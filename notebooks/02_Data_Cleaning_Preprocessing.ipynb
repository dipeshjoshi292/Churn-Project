# %%
import pandas as pd
import os
processed_file_path = os.path.join('..', 'data', 'processed', 'cleaned_merged_data.csv')
df_processed = pd.read_csv(processed_file_path)

print("Final processed data loaded from script output:")
print("Shape:", df_processed.shape)
print("\nColumns:", df_processed.columns.tolist())
print("\nFirst 5 rows:")
print(df_processed.head())
print("\nMissing values check:")
print(df_processed.isnull().sum())
# Out:
# Final processed data loaded from script output:
# Shape: (4999, 17)
#
# Columns: ['customer_id', 'total_revenue', 'average_order_value', 'transaction_count', 'first_purchase_date', 'last_purchase_date', 'customer_since', 'last_interaction', 'customer_tenure_months', 'days_since_last_purchase', 'days_since_last_interaction', 'customer_name', 'industry', 'company_size', 'support_tickets', 'satisfaction_score', 'churn_status']
#
# First 5 rows:
#   customer_id  total_revenue  average_order_value  transaction_count  \
# 0    CUST0001     1234008.41         77125.525625                 16
# 1    CUST0002     1545831.40        128819.283333                 12
# 2    CUST0003     1862004.54        310334.090000                  6
# 3    CUST0004     1051735.56         87644.630000                 12
# 4    CUST0005     1795474.77        224434.346250                  8
#
#   first_purchase_date last_purchase_date customer_since last_interaction  \
# ...
